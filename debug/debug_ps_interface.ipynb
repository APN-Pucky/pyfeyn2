# %%
from feynml.interface.madgraph.ps import ps_to_feynml

# %%
print((fml := ps_to_feynml("../tests/interface/loop_matrix.ps")).to_xml())
# Out:
# 75.0 710.0 115.0 635.0
# u 2 True False
# 115.0 635.0 75.0 560.0
# u~ 1 False True
# 115.0 635.0 155.0 635.0
# g None False False
# 195.0 635.0 155.0 635.0
# g None False False
# 155.0 635.0 195.0 635.0
# g None False False
# 257.28344 593.21855 235.0 635.0
# t~ 4 True False
# 235.0 635.0 257.28344 676.78145
# t 3 False True
# 195.0 635.0 235.0 635.0
# g None False False
# #
# 500.0 672.5 550.0 710.0
# t 3 False True
# 450.0 635.0 500.0 672.5
# g None False False
# 500.0 597.5 500.0 672.5
# t None False False
# 550.0 560.0 500.0 597.5
# t~ 4 True False
# 450.0 635.0 500.0 597.5
# g None False False
# 350.0 710.0 400.0 635.0
# u 2 True False
# 400.0 635.0 350.0 560.0
# u~ 1 False True
# 400.0 635.0 450.0 635.0
# g None False False
# #
# 175.0 415.0 225.0 452.5
# t~ None False False
# 225.0 452.5 275.0 490.0
# t 3 False True
# 225.0 452.5 225.0 377.5
# g None False False
# 275.0 340.0 225.0 377.5
# t~ 4 True False
# 225.0 377.5 175.0 415.0
# t~ None False False
# ...

# %%
fml
# Out:
# <wand.image.Image: 8220ea7 'PDF' (450x412)>
# <wand.image.Image: f56b29d 'PDF' (413x412)>
# <wand.image.Image: f93c61a 'PDF' (413x412)>
# <wand.image.Image: 48899cb 'PDF' (410x412)>
# <wand.image.Image: bc98453 'PDF' (410x412)>
# <wand.image.Image: 33ff7b5 'PDF' (410x412)>
# <wand.image.Image: 2261d51 'PDF' (410x412)>
# <wand.image.Image: 7fe5c20 'PDF' (450x412)>
# <wand.image.Image: 3d9fdd9 'PDF' (450x412)>
# <wand.image.Image: a7b7dfa 'PDF' (450x412)>
# <wand.image.Image: 2dca4f3 'PDF' (450x412)>

# %%
print(ps_to_feynml("../tests/interface/born_matrix.ps").to_xml())
# Out:
# 75.0 710.0 141.66667 635.0
# u 2 True False
# 141.66667 635.0 75.0 560.0
# u~ 1 False True
# 141.66667 635.0 208.33333 635.0
# g None False False
# 263.80335 572.59623 208.33333 635.0
# t~ 4 True False
# 208.33333 635.0 263.80335 697.40377
# t 3 False True
# #
# <?xml version="1.0" encoding="UTF-8"?>
# <feynml version="0.2.23">
#   <head>
#     <meta name="pyfeyn2" content="test"/>
#     <meta name="description" content="Simple single test diagram"/>
#     <meta name="feynml" content="0.2.23"/>
#     <style/>
#   </head>
#   <diagram id="FeynmanDiagram19" style="" sheet="">
#     <propagator id="9" pdgid="21" type="gluon" style="">
#       <name>g</name>
#       <source>2</source>
#       <target>8</target>
#     </propagator>
#     <vertex id="2" style=""/>
#     <vertex id="8" style=""/>
#     <leg id="3" pdgid="2" type="fermion" style="" external="2">
#       <name>u</name>
#       <target>2</target>
#       <sense>incoming</sense>
#     </leg>
# ...

# %%
ps_to_feynml("../tests/interface/born_matrix.ps")
# Out:
# 75.0 710.0 141.66667 635.0
# u 2 True False
# 141.66667 635.0 75.0 560.0
# u~ 1 False True
# 141.66667 635.0 208.33333 635.0
# g None False False
# 263.80335 572.59623 208.33333 635.0
# t~ 4 True False
# 208.33333 635.0 263.80335 697.40377
# t 3 False True
# #
# <wand.image.Image: b94e3a3 'PDF' (410x412)>

# %%
print(ps_to_feynml("../tests/interface/lo.ps").to_xml())
# Out:
# 75.0 560.0 141.66667 635.0
# u 1 True False
# 141.66667 635.0 75.0 710.0
# u~ 2 False True
# 208.33333 635.0 141.66667 635.0
# gamma None False False
# 263.80335 572.59623 208.33333 635.0
# e+ 3 True False
# 208.33333 635.0 263.80335 697.40377
# e- 4 False True
# #
# 350.0 560.0 416.66667 635.0
# u 1 True False
# 416.66667 635.0 350.0 710.0
# u~ 2 False True
# 483.33333 635.0 416.66667 635.0
# Z0 None False False
# 538.80335 572.59623 483.33333 635.0
# e+ 3 True False
# 483.33333 635.0 538.80335 697.40377
# e- 4 False True
# #
# <?xml version="1.0" encoding="UTF-8"?>
# <feynml version="0.2.23">
#   <head>
#     <meta name="pyfeyn2" content="test"/>
#     <meta name="description" content="Simple single test diagram"/>
#     <meta name="feynml" content="0.2.23"/>
#     <style/>
#   </head>
#   <diagram id="FeynmanDiagram21" style="" sheet="">
#     <propagator id="9" pdgid="22" type="photon" style="">
#       <name>gamma</name>
#       <source>7</source>
#       <target>2</target>
# ...

# %%
ps_to_feynml("../tests/interface/lo.ps")
# Out:
# 75.0 560.0 141.66667 635.0
# u 1 True False
# 141.66667 635.0 75.0 710.0
# u~ 2 False True
# 208.33333 635.0 141.66667 635.0
# gamma None False False
# 263.80335 572.59623 208.33333 635.0
# e+ 3 True False
# 208.33333 635.0 263.80335 697.40377
# e- 4 False True
# #
# 350.0 560.0 416.66667 635.0
# u 1 True False
# 416.66667 635.0 350.0 710.0
# u~ 2 False True
# 483.33333 635.0 416.66667 635.0
# Z0 None False False
# 538.80335 572.59623 483.33333 635.0
# e+ 3 True False
# 483.33333 635.0 538.80335 697.40377
# e- 4 False True
# #
# <wand.image.Image: 6da9ab4 'PDF' (410x412)>
# <wand.image.Image: 90312ae 'PDF' (410x412)>

# %%
print(ps_to_feynml("../tests/interface/born.ps").to_xml())
# Out:
# 75.0 560.0 141.66667 635.0
# g 1 True False
# 75.0 710.0 141.66667 635.0
# g 2 True False
# 141.66667 635.0 208.33333 635.0
# g None False False
# 263.80335 572.59623 208.33333 635.0
# t~ 4 True False
# 208.33333 635.0 263.80335 697.40377
# t 3 False True
# #
# 450.0 597.5 550.0 560.0
# t 3 False True
# 350.0 560.0 450.0 597.5
# g 1 True False
# 450.0 672.5 450.0 597.5
# t~ None False False
# 550.0 710.0 450.0 672.5
# t~ 4 True False
# 350.0 710.0 450.0 672.5
# g 2 True False
# #
# 275.0 340.0 175.0 377.5
# t~ 4 True False
# 75.0 340.0 175.0 377.5
# g 1 True False
# 175.0 377.5 175.0 452.5
# t None False False
# 175.0 452.5 275.0 490.0
# t 3 False True
# 75.0 490.0 175.0 452.5
# g 2 True False
# #
# <?xml version="1.0" encoding="UTF-8"?>
# <feynml version="0.2.23">
#   <head>
#     <meta name="pyfeyn2" content="test"/>
#     <meta name="description" content="Simple single test diagram"/>
#     <meta name="feynml" content="0.2.23"/>
#     <style/>
#   </head>
# ...

# %%
ps_to_feynml("../tests/interface/born.ps")
# Out:
# 75.0 560.0 141.66667 635.0
# g 1 True False
# 75.0 710.0 141.66667 635.0
# g 2 True False
# 141.66667 635.0 208.33333 635.0
# g None False False
# 263.80335 572.59623 208.33333 635.0
# t~ 4 True False
# 208.33333 635.0 263.80335 697.40377
# t 3 False True
# #
# 450.0 597.5 550.0 560.0
# t 3 False True
# 350.0 560.0 450.0 597.5
# g 1 True False
# 450.0 672.5 450.0 597.5
# t~ None False False
# 550.0 710.0 450.0 672.5
# t~ 4 True False
# 350.0 710.0 450.0 672.5
# g 2 True False
# #
# 275.0 340.0 175.0 377.5
# t~ 4 True False
# 75.0 340.0 175.0 377.5
# g 1 True False
# 175.0 377.5 175.0 452.5
# t None False False
# 175.0 452.5 275.0 490.0
# t 3 False True
# 75.0 490.0 175.0 452.5
# g 2 True False
# #
# <wand.image.Image: f4b7482 'PDF' (410x413)>
# <wand.image.Image: 253d21a 'PDF' (410x414)>
# <wand.image.Image: 9532ba6 'PDF' (410x414)>

# %%
ps_to_feynml("../tests/interface/matrix_1.ps")
# Out:
# 75.0 560.0 125.0 635.0
# g 1 True False
# 75.0 710.0 125.0 635.0
# g 2 True False
# 125.0 635.0 175.0 635.0
# g None False False
# 275.0 560.0 225.0 597.5
# t~ 4 True False
# 225.0 597.5 275.0 635.0
# t 3 False True
# 175.0 635.0 225.0 597.5
# g None False False
# 175.0 635.0 228.03301 674.77476
# g 5 False True
# #
# 500.0 672.5 550.0 635.0
# t 3 False True
# 500.0 672.5 550.0 710.0
# g 5 False True
# 450.0 635.0 500.0 672.5
# t None False False
# 350.0 560.0 400.0 635.0
# g 1 True False
# 350.0 710.0 400.0 635.0
# g 2 True False
# 400.0 635.0 450.0 635.0
# g None False False
# 503.03301 595.22524 450.0 635.0
# t~ 4 True False
# #
# 275.0 340.0 225.0 377.5
# t~ 4 True False
# 225.0 377.5 275.0 415.0
# g 5 False True
# 225.0 377.5 175.0 415.0
# t~ None False False
# 75.0 340.0 125.0 415.0
# g 1 True False
# 75.0 490.0 125.0 415.0
# g 2 True False
# 125.0 415.0 175.0 415.0
# g None False False
# 175.0 415.0 228.03301 454.77476
# t 3 False True
# #
# 550.0 490.0 450.0 465.0
# ...

# %%
ps_to_feynml("../tests/interface/matrix_2.ps")
# Out:
# 75.0 710.0 125.0 635.0
# u 2 True False
# 75.0 560.0 125.0 635.0
# g 1 True False
# 125.0 635.0 175.0 635.0
# u None False False
# 275.0 635.0 225.0 672.5
# t~ 4 True False
# 225.0 672.5 275.0 710.0
# t 3 False True
# 175.0 635.0 225.0 672.5
# g None False False
# 175.0 635.0 228.03301 595.22524
# u 5 False True
# #
# 450.0 585.0 550.0 560.0
# t 3 False True
# 350.0 560.0 450.0 585.0
# g 1 True False
# 450.0 635.0 450.0 585.0
# t~ None False False
# 350.0 710.0 450.0 685.0
# u 2 True False
# 450.0 685.0 550.0 710.0
# u 5 False True
# 450.0 685.0 450.0 635.0
# g None False False
# 550.0 635.0 450.0 635.0
# t~ 4 True False
# #
# 275.0 340.0 175.0 365.0
# t~ 4 True False
# 75.0 340.0 175.0 365.0
# g 1 True False
# 175.0 365.0 175.0 415.0
# t None False False
# 75.0 490.0 175.0 465.0
# u 2 True False
# 175.0 465.0 275.0 490.0
# u 5 False True
# 175.0 465.0 175.0 415.0
# g None False False
# 175.0 415.0 275.0 415.0
# t 3 False True
# #
# 416.66667 377.5 510.29958 351.16574
# ...
