# %% [markdown]
# # All

# %% [markdown]
# A large collection of Feynman diagrams to check if the automatic vertex and leg placement still produces good results. Also shows the performance.

# %%
from feynml.topology import generate_topologies
from feynml.topology import four

# %% [markdown]
# ## 2 -> 2

# %%
# %%time
generate_topologies(2,2,0)
# Out:
# CPU times: user 7.61 ms, sys: 3.01 ms, total: 10.6 ms
# Wall time: 9.4 ms
# <wand.image.Image: 3932e79 'PDF' (371x371)>
# <wand.image.Image: d1e7ed3 'PDF' (371x371)>
# <wand.image.Image: e7ccd05 'PDF' (371x371)>
# <wand.image.Image: 850a9b2 'PDF' (371x371)>

# %%
# %%time
generate_topologies(2,2,1)
# Out:
# CPU times: user 22.4 s, sys: 105 ms, total: 22.5 s
# Wall time: 22.6 s
# /home/apn/git/pyfeyn2/pyfeyn2/render/latex/tikzfeynman.py:81: UserWarning: No type or style set for connector  Propagator873 None None
#   warnings.warn(
# <wand.image.Image: 3910e81 'PDF' (371x371)>
# /home/apn/git/pyfeyn2/pyfeyn2/render/latex/tikzfeynman.py:81: UserWarning: No type or style set for connector  Propagator874 None None
#   warnings.warn(
# <wand.image.Image: 47cf15e 'PDF' (368x368)>
# /home/apn/git/pyfeyn2/pyfeyn2/render/latex/tikzfeynman.py:81: UserWarning: No type or style set for connector  Propagator875 None None
#   warnings.warn(
# <wand.image.Image: 0a6f3dc 'PDF' (368x368)>
# /home/apn/git/pyfeyn2/pyfeyn2/render/latex/tikzfeynman.py:81: UserWarning: No type or style set for connector  Propagator876 None None
#   warnings.warn(
# <wand.image.Image: add6c18 'PDF' (371x371)>
# ...

# %% [markdown]
# ## 2 -> 3

# %%
# %%time
generate_topologies(2,3,0)
# Out:
# CPU times: user 306 ms, sys: 374 μs, total: 307 ms
# Wall time: 304 ms
# <wand.image.Image: 8d07c00 'PDF' (364x364)>
